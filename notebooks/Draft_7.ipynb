# %%
#Imports

import numpy as np
import random
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error , accuracy_score , precision_score , recall_score , f1_score , confusion_matrix , classification_report

import tensorflow as tf
from tensorflow.keras.models import Sequential , Model
from tensorflow.keras.layers import Input, Conv1D, MaxPooling1D, Flatten, Dense, LSTM, GRU, Dropout, BatchNormalization, Bidirectional, Attention, GlobalAveragePooling1D, LayerNormalization,  MultiHeadAttention, Add ,Multiply, LayerNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.losses import Huber

# Set random seeds for reproducibility
SEED = 42
np.random.seed(SEED)
tf.random.set_seed(SEED)
random.seed(SEED)

# %%
#Data Loading and Preprocessing

# Load training data
train_df = pd.read_csv("train_FD001.txt", sep=r"\s+", header=None)
train_df.columns = ['id', 'cycle', 'op1', 'op2', 'op3'] + [f's{i}' for i in range(1, 22)]

# Compute Remaining Useful Life (RUL)
max_cycle = train_df.groupby('id')['cycle'].max().reset_index().rename(columns={'cycle': 'max_cycle'})
train_df = train_df.merge(max_cycle, on='id')
train_df['RUL'] = train_df['max_cycle'] - train_df['cycle']
train_df.drop(columns=['max_cycle'], inplace=True)

# Cap RUL values for stability
train_df['RUL'] = train_df['RUL'].clip(upper=125)

# Drop unused operational/sensor columns
drop_cols = ['op3', 's1', 's5', 's10', 's16', 's18', 's19']
train_df = train_df.drop(columns=drop_cols)

# Separate features and target
feature_cols = [col for col in train_df.columns if col not in ['id', 'RUL']]
X = train_df[feature_cols].copy()
y = train_df['RUL'].copy()

# Standardize features
scaler = StandardScaler()
X[feature_cols] = scaler.fit_transform(X[feature_cols])

# %%
# SEQUENCE CREATION

processed_df = X.copy()
processed_df['RUL'] = y.values
processed_df['id'] = train_df['id'].values

sequence_length = 30
engine_ids = processed_df['id'].unique()
train_engine_ids, val_engine_ids = train_test_split(
    engine_ids, test_size=0.20, random_state=SEED
)
train_df_split = processed_df[processed_df['id'].isin(train_engine_ids)]
val_df_split = processed_df[processed_df['id'].isin(val_engine_ids)]

# Sequence Creation Function
def create_sequences(df, sequence_length):
    X_seqs, y_seqs = [], []
    for engine_id in df['id'].unique():
        engine_data = df[df['id'] == engine_id].drop(columns=['id'])
        data_array = engine_data.values
        for i in range(len(data_array) - sequence_length):
            X_seqs.append(data_array[i:i+sequence_length, :-1])
            y_seqs.append(data_array[i+sequence_length, -1])
    return np.array(X_seqs), np.array(y_seqs)

# Create Train and Validation Sequences
X_train, y_train = create_sequences(train_df_split, sequence_length)
X_val, y_val = create_sequences(val_df_split, sequence_length)

print(f"Shape of X_train: {X_train.shape}, y_train: {y_train.shape}")
print(f"Shape of X_val:   {X_val.shape}, y_val:   {y_val.shape}")
# Out:
# Shape of X_train: (14161, 30, 18), y_train: (14161,)
# Shape of X_val:   (3470, 30, 18), y_val:   (3470,)

# %%
# Callbacks
callbacks_cnn = [
    EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True),
    ReduceLROnPlateau(monitor='val_loss', factor=0.8, patience=5, min_lr=1e-5, verbose=1)
]

callbacks_rnn = [
    EarlyStopping(monitor='val_loss', patience=15, restore_best_weights=True),
    ReduceLROnPlateau(monitor='val_loss', factor=0.8, patience=6, min_lr=1e-6, verbose=1)
]

# %%
# 1. ANN + Attention
ann_inputs = Input(shape=(sequence_length, X_train.shape[2]))
ann_x = Dense(64, activation='relu')(ann_inputs)
ann_attention = Attention()([ann_x, ann_x])
ann_x = GlobalAveragePooling1D()(ann_attention)
ann_x = Dense(64, activation='relu')(ann_x)
ann_x = Dropout(0.2)(ann_x)
ann_outputs = Dense(1)(ann_x)
ann_model = Model(ann_inputs, ann_outputs)
ann_model.compile(optimizer=Adam(1e-3), loss=Huber(), metrics=['mae'])
history_ann = ann_model.fit(X_train, y_train, validation_data=(X_val, y_val), 
                            epochs=60, batch_size=64, callbacks=callbacks_rnn, verbose=1)
# Out:
# Epoch 1/60
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 72.2721 - mae: 72.7714 - val_loss: 62.2394 - val_mae: 62.7392 - learning_rate: 0.0010
# Epoch 2/60
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 75.2858 - mae: 75.7850 - val_loss: 50.2015 - val_mae: 50.7006 - learning_rate: 0.0010
# Epoch 3/60
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 57.8831 - mae: 58.3817 - val_loss: 36.9986 - val_mae: 37.4963 - learning_rate: 0.0010
# Epoch 4/60
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 34.1944 - mae: 34.6916 - val_loss: 27.2314 - val_mae: 27.7276 - learning_rate: 0.0010
# Epoch 5/60
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 26.6195 - mae: 27.1149 - val_loss: 21.2168 - val_mae: 21.7130 - learning_rate: 0.0010
# Epoch 6/60
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 22.9521 - mae: 23.4475 - val_loss: 18.4880 - val_mae: 18.9830 - learning_rate: 0.0010
# Epoch 7/60
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 21.6058 - mae: 22.1015 - val_loss: 16.8098 - val_mae: 17.2999 - learning_rate: 0.0010
# Epoch 8/60
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 24.6878 - mae: 25.1835 - val_loss: 24.5750 - val_mae: 25.0729 - learning_rate: 0.0010
# Epoch 9/60
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 37.5794 - mae: 38.0765 - val_loss: 18.0656 - val_mae: 18.5618 - learning_rate: 0.0010
# Epoch 10/60
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 32.4434 - mae: 32.9410 - val_loss: 29.4370 - val_mae: 29.9346 - learning_rate: 0.0010
# Epoch 11/60
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 30.9197 - mae: 31.4163 - val_loss: 15.0897 - val_mae: 15.5847 - learning_rate: 0.0010
# Epoch 12/60
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 33.2265 - mae: 33.7233 - val_loss: 20.7684 - val_mae: 21.2653 - learning_rate: 0.0010
# Epoch 13/60
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 34.0978 - mae: 34.5950 - val_loss: 15.7107 - val_mae: 16.2015 - learning_rate: 0.0010
# Epoch 14/60
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 34.5891 - mae: 35.0861 - val_loss: 15.2160 - val_mae: 15.7054 - learning_rate: 0.0010
# Epoch 15/60
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 34.1289 - mae: 34.6254 - val_loss: 18.4129 - val_mae: 18.9068 - learning_rate: 0.0010
# Epoch 16/60
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 33.5918 - mae: 34.0885 - val_loss: 14.9345 - val_mae: 15.4268 - learning_rate: 0.0010
# Epoch 17/60
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 30.8317 - mae: 31.3282 - val_loss: 18.0550 - val_mae: 18.5500 - learning_rate: 0.0010
# Epoch 18/60
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 31.0257 - mae: 31.5221 - val_loss: 17.1252 - val_mae: 17.6200 - learning_rate: 0.0010
# Epoch 19/60
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 29.4685 - mae: 29.9650 - val_loss: 15.7068 - val_mae: 16.2010 - learning_rate: 0.0010
# Epoch 20/60
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 27.8994 - mae: 28.3955 - val_loss: 16.1343 - val_mae: 16.6268 - learning_rate: 0.0010
# Epoch 21/60
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 27.0891 - mae: 27.5853 - val_loss: 16.3405 - val_mae: 16.8336 - learning_rate: 0.0010
# Epoch 22/60
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 26.8054 - mae: 27.3019 - val_loss: 14.7200 - val_mae: 15.2136 - learning_rate: 0.0010
# Epoch 23/60
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 25.7107 - mae: 26.2068 - val_loss: 17.4866 - val_mae: 17.9823 - learning_rate: 0.0010
# Epoch 24/60
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 25.3452 - mae: 25.8412 - val_loss: 14.3485 - val_mae: 14.8426 - learning_rate: 0.0010
# Epoch 25/60
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 24.8379 - mae: 25.3336 - val_loss: 14.8706 - val_mae: 15.3623 - learning_rate: 0.0010
# Epoch 26/60
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 24.0138 - mae: 24.5094 - val_loss: 17.8209 - val_mae: 18.3174 - learning_rate: 0.0010
# Epoch 27/60
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 24.0257 - mae: 24.5215 - val_loss: 15.5597 - val_mae: 16.0535 - learning_rate: 0.0010
# Epoch 28/60
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 23.8559 - mae: 24.3512 - val_loss: 16.3379 - val_mae: 16.8317 - learning_rate: 0.0010
# Epoch 29/60
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 23.7892 - mae: 24.2847 - val_loss: 16.7879 - val_mae: 17.2828 - learning_rate: 0.0010
# Epoch 30/60
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 23.3057 - mae: 23.8014 - val_loss: 14.2539 - val_mae: 14.7461 - learning_rate: 0.0010
# Epoch 31/60
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 23.5701 - mae: 24.0653 - val_loss: 16.5263 - val_mae: 17.0218 - learning_rate: 0.0010
# Epoch 32/60
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 23.3949 - mae: 23.8906 - val_loss: 15.6188 - val_mae: 16.1129 - learning_rate: 0.0010
# Epoch 33/60
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 23.0764 - mae: 23.5720 - val_loss: 14.4297 - val_mae: 14.9211 - learning_rate: 0.0010
# Epoch 34/60
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 23.1822 - mae: 23.6777 - val_loss: 14.4074 - val_mae: 14.9008 - learning_rate: 0.0010
# Epoch 35/60
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 23.2372 - mae: 23.7329 - val_loss: 14.8378 - val_mae: 15.3305 - learning_rate: 0.0010
# Epoch 36/60
# 220/222 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 23.5829 - mae: 24.0785
# Epoch 36: ReduceLROnPlateau reducing learning rate to 0.000800000037997961.
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 23.3335 - mae: 23.8290 - val_loss: 14.7141 - val_mae: 15.2049 - learning_rate: 0.0010
# Epoch 37/60
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 22.8492 - mae: 23.3446 - val_loss: 16.5391 - val_mae: 17.0336 - learning_rate: 8.0000e-04
# Epoch 38/60
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 22.8511 - mae: 23.3467 - val_loss: 14.4609 - val_mae: 14.9507 - learning_rate: 8.0000e-04
# Epoch 39/60
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 22.5489 - mae: 23.0436 - val_loss: 14.6066 - val_mae: 15.0933 - learning_rate: 8.0000e-04
# Epoch 40/60
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 22.8899 - mae: 23.3852 - val_loss: 14.3555 - val_mae: 14.8469 - learning_rate: 8.0000e-04
# Epoch 41/60
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 22.7001 - mae: 23.1952 - val_loss: 14.9952 - val_mae: 15.4872 - learning_rate: 8.0000e-04
# Epoch 42/60
# 221/222 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 22.6155 - mae: 23.1114
# Epoch 42: ReduceLROnPlateau reducing learning rate to 0.0006400000303983689.
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 22.6216 - mae: 23.1171 - val_loss: 14.8583 - val_mae: 15.3481 - learning_rate: 8.0000e-04
# Epoch 43/60
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 22.7637 - mae: 23.2591 - val_loss: 14.4258 - val_mae: 14.9166 - learning_rate: 6.4000e-04
# Epoch 44/60
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 22.9568 - mae: 23.4526 - val_loss: 14.3423 - val_mae: 14.8353 - learning_rate: 6.4000e-04
# Epoch 45/60
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 22.6093 - mae: 23.1051 - val_loss: 14.4434 - val_mae: 14.9320 - learning_rate: 6.4000e-04

# %%
# 2. BiLSTM + Attention
lstm_inputs = Input(shape=(sequence_length, X_train.shape[2]))
lstm_x = Bidirectional(LSTM(64, return_sequences=True))(lstm_inputs)
lstm_x = BatchNormalization()(lstm_x)
lstm_x = Dropout(0.1)(lstm_x)
attention_output = MultiHeadAttention(num_heads=4, key_dim=32)(lstm_x, lstm_x)
lstm_x = Add()([lstm_x, attention_output])
lstm_x = LayerNormalization()(lstm_x)
lstm_x = GlobalAveragePooling1D()(lstm_x)
lstm_x = Dense(64, activation='relu')(lstm_x)
lstm_x = Dropout(0.2)(lstm_x)
lstm_outputs = Dense(1)(lstm_x)
lstm_model = Model(lstm_inputs, lstm_outputs)
lstm_model.compile(optimizer=Adam(1e-4), loss=Huber(), metrics=['mae'])
history_lstm = lstm_model.fit(X_train, y_train, validation_data=(X_val, y_val),
                    epochs=60, batch_size=64, callbacks=callbacks_rnn, verbose=1)
# Out:
# Epoch 1/60
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 38s 147ms/step - loss: 78.8389 - mae: 79.3377 - val_loss: 77.1333 - val_mae: 77.6311 - learning_rate: 1.0000e-04
# Epoch 2/60
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 27s 124ms/step - loss: 75.5802 - mae: 76.0784 - val_loss: 70.6409 - val_mae: 71.1389 - learning_rate: 1.0000e-04
# Epoch 3/60
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 27s 123ms/step - loss: 62.5795 - mae: 63.0772 - val_loss: 52.1135 - val_mae: 52.6111 - learning_rate: 1.0000e-04
# Epoch 4/60
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 27s 124ms/step - loss: 40.6759 - mae: 41.1721 - val_loss: 30.2920 - val_mae: 30.7891 - learning_rate: 1.0000e-04
# Epoch 5/60
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 27s 123ms/step - loss: 22.9601 - mae: 23.4551 - val_loss: 17.7389 - val_mae: 18.2355 - learning_rate: 1.0000e-04
# Epoch 6/60
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - loss: 16.6013 - mae: 17.0945
# Epoch 6: ReduceLROnPlateau reducing learning rate to 7.999999797903001e-05.
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 27s 123ms/step - loss: 16.0023 - mae: 16.4950 - val_loss: 11.4534 - val_mae: 11.9461 - learning_rate: 1.0000e-04
# Epoch 7/60
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 28s 124ms/step - loss: 14.2625 - mae: 14.7548 - val_loss: 10.9994 - val_mae: 11.4923 - learning_rate: 8.0000e-05
# Epoch 8/60
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 28s 124ms/step - loss: 13.5706 - mae: 14.0621 - val_loss: 9.7850 - val_mae: 10.2743 - learning_rate: 8.0000e-05
# Epoch 9/60
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 30s 137ms/step - loss: 13.2742 - mae: 13.7645 - val_loss: 9.5522 - val_mae: 10.0419 - learning_rate: 8.0000e-05
# Epoch 10/60
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 30s 134ms/step - loss: 12.8800 - mae: 13.3708 - val_loss: 9.8985 - val_mae: 10.3870 - learning_rate: 8.0000e-05
# Epoch 11/60
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 29s 128ms/step - loss: 12.6137 - mae: 13.1037 - val_loss: 9.3333 - val_mae: 9.8198 - learning_rate: 8.0000e-05
# Epoch 12/60
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 29s 132ms/step - loss: 12.3155 - mae: 12.8056 - val_loss: 9.1463 - val_mae: 9.6303 - learning_rate: 8.0000e-05
# Epoch 13/60
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 29s 130ms/step - loss: 12.0701 - mae: 12.5598 - val_loss: 9.3617 - val_mae: 9.8478 - learning_rate: 8.0000e-05
# Epoch 14/60
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 29s 128ms/step - loss: 11.9642 - mae: 12.4538 - val_loss: 9.3912 - val_mae: 9.8793 - learning_rate: 8.0000e-05
# Epoch 15/60
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 29s 128ms/step - loss: 11.7064 - mae: 12.1961 - val_loss: 8.8996 - val_mae: 9.3867 - learning_rate: 8.0000e-05
# Epoch 16/60
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 27s 124ms/step - loss: 11.4609 - mae: 11.9507 - val_loss: 9.0180 - val_mae: 9.5060 - learning_rate: 8.0000e-05
# Epoch 17/60
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 27s 124ms/step - loss: 11.3121 - mae: 11.8012 - val_loss: 8.6066 - val_mae: 9.0933 - learning_rate: 8.0000e-05
# Epoch 18/60
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 28s 126ms/step - loss: 11.2129 - mae: 11.7015 - val_loss: 8.5133 - val_mae: 8.9963 - learning_rate: 8.0000e-05
# Epoch 19/60
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 28s 124ms/step - loss: 10.9065 - mae: 11.3948 - val_loss: 8.6280 - val_mae: 9.1099 - learning_rate: 8.0000e-05
# Epoch 20/60
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 28s 124ms/step - loss: 10.8644 - mae: 11.3525 - val_loss: 8.9053 - val_mae: 9.3917 - learning_rate: 8.0000e-05
# Epoch 21/60
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 28s 124ms/step - loss: 10.6759 - mae: 11.1644 - val_loss: 8.6093 - val_mae: 9.0879 - learning_rate: 8.0000e-05
# Epoch 22/60
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 28s 124ms/step - loss: 10.4946 - mae: 10.9830 - val_loss: 8.6299 - val_mae: 9.1137 - learning_rate: 8.0000e-05
# Epoch 23/60
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 28s 124ms/step - loss: 10.4557 - mae: 10.9433 - val_loss: 8.3170 - val_mae: 8.7949 - learning_rate: 8.0000e-05
# Epoch 24/60
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 28s 125ms/step - loss: 10.3171 - mae: 10.8044 - val_loss: 8.6206 - val_mae: 9.1064 - learning_rate: 8.0000e-05
# Epoch 25/60
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 28s 124ms/step - loss: 10.1519 - mae: 10.6393 - val_loss: 8.5621 - val_mae: 9.0419 - learning_rate: 8.0000e-05
# Epoch 26/60
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 28s 124ms/step - loss: 10.0653 - mae: 10.5524 - val_loss: 8.6782 - val_mae: 9.1571 - learning_rate: 8.0000e-05
# Epoch 27/60
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 27s 124ms/step - loss: 9.9639 - mae: 10.4504 - val_loss: 8.6021 - val_mae: 9.0851 - learning_rate: 8.0000e-05
# Epoch 28/60
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 28s 124ms/step - loss: 9.8712 - mae: 10.3571 - val_loss: 9.0435 - val_mae: 9.5245 - learning_rate: 8.0000e-05
# Epoch 29/60
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - loss: 9.6253 - mae: 10.1112
# Epoch 29: ReduceLROnPlateau reducing learning rate to 6.399999838322402e-05.
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 28s 128ms/step - loss: 9.7931 - mae: 10.2793 - val_loss: 9.0247 - val_mae: 9.5068 - learning_rate: 8.0000e-05
# Epoch 30/60
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 28s 125ms/step - loss: 9.6180 - mae: 10.1053 - val_loss: 9.1739 - val_mae: 9.6569 - learning_rate: 6.4000e-05
# Epoch 31/60
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 28s 126ms/step - loss: 9.5043 - mae: 9.9897 - val_loss: 9.0341 - val_mae: 9.5166 - learning_rate: 6.4000e-05
# Epoch 32/60
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 29s 129ms/step - loss: 9.3049 - mae: 9.7913 - val_loss: 8.7219 - val_mae: 9.2017 - learning_rate: 6.4000e-05
# Epoch 33/60
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 30s 133ms/step - loss: 9.3084 - mae: 9.7943 - val_loss: 9.0924 - val_mae: 9.5771 - learning_rate: 6.4000e-05
# Epoch 34/60
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 29s 130ms/step - loss: 9.2504 - mae: 9.7360 - val_loss: 9.0586 - val_mae: 9.5429 - learning_rate: 6.4000e-05
# Epoch 35/60
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - loss: 9.0117 - mae: 9.4964
# Epoch 35: ReduceLROnPlateau reducing learning rate to 5.119999987073243e-05.
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 28s 125ms/step - loss: 9.0821 - mae: 9.5676 - val_loss: 9.3790 - val_mae: 9.8606 - learning_rate: 6.4000e-05
# Epoch 36/60
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 28s 125ms/step - loss: 9.0873 - mae: 9.5720 - val_loss: 9.3586 - val_mae: 9.8422 - learning_rate: 5.1200e-05
# Epoch 37/60
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 28s 126ms/step - loss: 9.0690 - mae: 9.5542 - val_loss: 9.3766 - val_mae: 9.8627 - learning_rate: 5.1200e-05
# Epoch 38/60
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 28s 125ms/step - loss: 8.9077 - mae: 9.3941 - val_loss: 9.2650 - val_mae: 9.7457 - learning_rate: 5.1200e-05

# %%
# 2. Improved BiLSTM + Attention

lstm_inputs = Input(shape=(sequence_length, X_train.shape[2]))

lstm_x = Bidirectional(
    LSTM(
        64,
        return_sequences=True,
        recurrent_dropout=0.05
    )
)(lstm_inputs)

# REMOVE BatchNorm
lstm_x = Dropout(0.05)(lstm_x)

# MultiHead Self Attention
attention_output = MultiHeadAttention(
    num_heads=4,
    key_dim=32,
    dropout=0.05
)(lstm_x, lstm_x)

# Residual connection
lstm_x = Add()([lstm_x, attention_output])
lstm_x = LayerNormalization()(lstm_x)

# Feed Forward Network
ffn = Dense(128, activation='relu')(lstm_x)
ffn = Dense(lstm_x.shape[-1])(ffn)

# Residual connection
lstm_x = Add()([lstm_x, ffn])
lstm_x = LayerNormalization()(lstm_x)

# Pooling
lstm_x = GlobalAveragePooling1D()(lstm_x)

# Dense layers
lstm_x = Dense(64, activation='relu')(lstm_x)

# LOWER dropout
lstm_x = Dropout(0.1)(lstm_x)

lstm_outputs = Dense(1)(lstm_x)

lstm_model = Model(lstm_inputs, lstm_outputs)

lstm_model.compile(
    optimizer=Adam(8e-5),
    loss=Huber(),
    metrics=['mae']
)

history_lstm = lstm_model.fit(
    X_train,
    y_train,
    validation_data=(X_val, y_val),
    epochs=60,
    batch_size=64,
    callbacks=callbacks_rnn,
    verbose=1
)
# Out:
# 2026-05-15 14:40:15.774226: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M5
# 2026-05-15 14:40:15.774282: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 16.00 GB
# 2026-05-15 14:40:15.774290: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 5.92 GB
# 2026-05-15 14:40:15.774353: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2026-05-15 14:40:15.774383: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# Epoch 1/60
# 2026-05-15 14:40:17.795612: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
#  10/222 ━━━━━━━━━━━━━━━━━━━━ 10:59 3s/step - loss: 78.7837 - mae: 79.2806
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 54
#      50     loss=Huber(),
#      51     metrics=['mae']
#      52 )
#      53
# ---> 54 history_lstm = lstm_model.fit(
#      55     X_train,
#      56     y_train,
#      57     validation_data=(X_val, y_val),
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/keras/src/backend/tensorflow/trainer.py:399, in TensorFlowTrainer.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     397 for begin_step, end_step, iterator in epoch_iterator:
#     398     callbacks.on_train_batch_begin(begin_step)
# --> 399     logs = self.train_function(iterator)
#     400     callbacks.on_train_batch_end(end_step, logs)
#     401     if self.stop_training:
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/keras/src/backend/tensorflow/trainer.py:241, in TensorFlowTrainer._make_function.<locals>.function(iterator)
#     237 def function(iterator):
#     238     if isinstance(
#     239         iterator, (tf.data.Iterator, tf.distribute.DistributedIterator)
#     240     ):
# --> 241         opt_outputs = multi_step_on_iterator(iterator)
#     242         if not opt_outputs.has_value():
#     243             raise StopIteration
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:833, in Function.__call__(self, *args, **kwds)
#     830 compiler = "xla" if self._jit_compile else "nonXla"
#     832 with OptionalXlaContext(self._jit_compile):
# --> 833   result = self._call(*args, **kwds)
#     835 new_tracing_count = self.experimental_get_tracing_count()
#     836 without_tracing = (tracing_count == new_tracing_count)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:878, in Function._call(self, *args, **kwds)
#     875 self._lock.release()
#     876 # In this case we have not created variables on the first call. So we can
#     877 # run the first trace but we should fail if variables are created.
# --> 878 results = tracing_compilation.call_function(
#     879     args, kwds, self._variable_creation_config
#     880 )
#     881 if self._created_variables:
#     882   raise ValueError("Creating variables on a non-first call to a function"
#     883                    " decorated with tf.function.")
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py:139, in call_function(args, kwargs, tracing_options)
#     137 bound_args = function.function_type.bind(*args, **kwargs)
#     138 flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139 return function._call_flat(  # pylint: disable=protected-access
#     140     flat_inputs, captured_inputs=function.captured_inputs
#     141 )
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/concrete_function.py:1322, in ConcreteFunction._call_flat(self, tensor_inputs, captured_inputs)
#    1318 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1319 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1320     and executing_eagerly):
#    1321   # No tape is watching; skip to running the function.
# -> 1322   return self._inference_function.call_preflattened(args)
#    1323 forward_backward = self._select_forward_and_backward_functions(
#    1324     args,
#    1325     possible_gradient_type,
#    1326     executing_eagerly)
#    1327 forward_function, args_with_tangents = forward_backward.forward()
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:216, in AtomicFunction.call_preflattened(self, args)
#     214 def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215   """Calls with flattened tensor inputs and returns the structured output."""
# --> 216   flat_outputs = self.call_flat(*args)
#     217   return self.function_type.pack_output(flat_outputs)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:251, in AtomicFunction.call_flat(self, *args)
#     249 with record.stop_recording():
#     250   if self._bound_context.executing_eagerly():
# --> 251     outputs = self._bound_context.call_function(
#     252         self.name,
#     253         list(args),
#     254         len(self.function_type.flat_outputs),
#     255     )
#     256   else:
#     257     outputs = make_call_op_in_graph(
#     258         self,
#     259         list(args),
#     260         self._bound_context.function_call_options.as_attrs(),
#     261     )
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/tensorflow/python/eager/context.py:1500, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1498 cancellation_context = cancellation.context()
#    1499 if cancellation_context is None:
# -> 1500   outputs = execute.execute(
#    1501       name.decode("utf-8"),
#    1502       num_outputs=num_outputs,
#    1503       inputs=tensor_inputs,
#    1504       attrs=attrs,
#    1505       ctx=self,
#    1506   )
#    1507 else:
#    1508   outputs = execute.execute_with_cancellation(
#    1509       name.decode("utf-8"),
#    1510       num_outputs=num_outputs,
#    (...)   1514       cancellation_manager=cancellation_context,
#    1515   )
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/tensorflow/python/eager/execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:

# %%
# 3. CNN + Attention
cnn_inputs = Input(shape=(sequence_length, X_train.shape[2]))
cnn_x = Conv1D(64, kernel_size=3, activation='relu')(cnn_inputs)
cnn_x = BatchNormalization()(cnn_x)
cnn_x = MaxPooling1D(pool_size=2)(cnn_x)
cnn_x = Dropout(0.2)(cnn_x)
cnn_x = Conv1D(32, kernel_size=3, activation='relu')(cnn_x)
cnn_x = BatchNormalization()(cnn_x)
attention_weights = Dense(32, activation='softmax')(cnn_x)
cnn_attention = Multiply()([cnn_x, attention_weights])
cnn_x = Flatten()(cnn_attention)
cnn_x = Dense(64, activation='relu')(cnn_x)
cnn_x = Dropout(0.3)(cnn_x)
cnn_outputs = Dense(1)(cnn_x)
cnn_model = Model(cnn_inputs, cnn_outputs)
cnn_model.compile(optimizer=Adam(1e-3), loss=Huber(), metrics=['mae'])
history_cnn = cnn_model.fit(X_train, y_train, validation_data=(X_val, y_val),
                        epochs=60, batch_size=64, callbacks=callbacks_cnn, verbose=1)
# Out:
# Epoch 1/60
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 12s 30ms/step - loss: 46.6039 - mae: 47.1000 - val_loss: 17.8128 - val_mae: 18.3063 - learning_rate: 0.0010
# Epoch 2/60
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - loss: 15.1484 - mae: 15.6410 - val_loss: 12.9448 - val_mae: 13.4374 - learning_rate: 0.0010
# Epoch 3/60
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 6s 26ms/step - loss: 13.3837 - mae: 13.8737 - val_loss: 13.6024 - val_mae: 14.0956 - learning_rate: 0.0010
# Epoch 4/60
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 6s 27ms/step - loss: 12.2176 - mae: 12.7068 - val_loss: 11.8108 - val_mae: 12.3036 - learning_rate: 0.0010
# Epoch 5/60
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 6s 27ms/step - loss: 11.4103 - mae: 11.8991 - val_loss: 11.9329 - val_mae: 12.4244 - learning_rate: 0.0010
# Epoch 6/60
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 6s 28ms/step - loss: 10.8301 - mae: 11.3186 - val_loss: 12.9972 - val_mae: 13.4881 - learning_rate: 0.0010
# Epoch 7/60
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 6s 29ms/step - loss: 10.3355 - mae: 10.8232 - val_loss: 12.0815 - val_mae: 12.5732 - learning_rate: 0.0010
# Epoch 8/60
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 8s 37ms/step - loss: 10.2060 - mae: 10.6935 - val_loss: 12.5060 - val_mae: 12.9971 - learning_rate: 0.0010
# Epoch 9/60
# 221/222 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 9.9276 - mae: 10.4158
# Epoch 9: ReduceLROnPlateau reducing learning rate to 0.000800000037997961.
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 9s 39ms/step - loss: 9.9244 - mae: 10.4126 - val_loss: 12.3568 - val_mae: 12.8442 - learning_rate: 0.0010
# Epoch 10/60
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 8s 38ms/step - loss: 9.5950 - mae: 10.0826 - val_loss: 11.5862 - val_mae: 12.0757 - learning_rate: 8.0000e-04
# Epoch 11/60
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 9s 42ms/step - loss: 9.2835 - mae: 9.7714 - val_loss: 11.8383 - val_mae: 12.3233 - learning_rate: 8.0000e-04
# Epoch 12/60
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 8s 38ms/step - loss: 9.1611 - mae: 9.6481 - val_loss: 11.8646 - val_mae: 12.3543 - learning_rate: 8.0000e-04
# Epoch 13/60
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 9s 38ms/step - loss: 9.2084 - mae: 9.6962 - val_loss: 12.1584 - val_mae: 12.6479 - learning_rate: 8.0000e-04
# Epoch 14/60
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 9s 39ms/step - loss: 8.9649 - mae: 9.4516 - val_loss: 11.6893 - val_mae: 12.1783 - learning_rate: 8.0000e-04
# Epoch 15/60
# 221/222 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 8.7640 - mae: 9.2502
# Epoch 15: ReduceLROnPlateau reducing learning rate to 0.0006400000303983689.
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 8s 38ms/step - loss: 8.7847 - mae: 9.2715 - val_loss: 12.3961 - val_mae: 12.8871 - learning_rate: 8.0000e-04
# Epoch 16/60
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 8s 36ms/step - loss: 9.1915 - mae: 9.6790 - val_loss: 12.4002 - val_mae: 12.8921 - learning_rate: 6.4000e-04
# Epoch 17/60
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 8s 36ms/step - loss: 9.4842 - mae: 9.9724 - val_loss: 12.5339 - val_mae: 13.0267 - learning_rate: 6.4000e-04
# Epoch 18/60
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 8s 34ms/step - loss: 9.5243 - mae: 10.0133 - val_loss: 12.2240 - val_mae: 12.7162 - learning_rate: 6.4000e-04
# Epoch 19/60
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 8s 35ms/step - loss: 9.2216 - mae: 9.7100 - val_loss: 11.9116 - val_mae: 12.4039 - learning_rate: 6.4000e-04
# Epoch 20/60
# 221/222 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 8.8804 - mae: 9.3691
# Epoch 20: ReduceLROnPlateau reducing learning rate to 0.0005120000336319208.
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 8s 34ms/step - loss: 8.9234 - mae: 9.4114 - val_loss: 11.8762 - val_mae: 12.3672 - learning_rate: 6.4000e-04

# %%
# 4. TRANSFORMER + ATTENTION MODEL
transformer_inputs = Input(shape=(sequence_length, X_train.shape[2]))
# Multi-Head Self Attention
attention_output = MultiHeadAttention(num_heads=4, key_dim=32)(transformer_inputs, transformer_inputs)
# Residual Connection
x = Add()([transformer_inputs, attention_output])
x = LayerNormalization()(x)
# Feed Forward Network
ffn = Dense(128, activation='relu')(x)
ffn = Dense(X_train.shape[2])(ffn)
# Residual Connection
x = Add()([x, ffn])
x = LayerNormalization()(x)
# Pooling + Dense
x = GlobalAveragePooling1D()(x)
x = Dense(64, activation='relu')(x)
x = Dropout(0.2)(x)
transformer_outputs = Dense(1)(x)
transformer_model = Model(transformer_inputs, transformer_outputs)
transformer_model.compile(optimizer=Adam(1e-4), loss=Huber(), metrics=['mae'])
history_transformer = transformer_model.fit(X_train, y_train, validation_data=(X_val, y_val), 
                                epochs=60, batch_size=64, callbacks=callbacks_rnn, verbose=1)
# Out:
# Epoch 1/60
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 11s 38ms/step - loss: 79.2731 - mae: 79.7728 - val_loss: 77.8050 - val_mae: 78.3050 - learning_rate: 1.0000e-04
# Epoch 2/60
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 8s 34ms/step - loss: 76.5264 - mae: 77.0262 - val_loss: 72.1246 - val_mae: 72.6233 - learning_rate: 1.0000e-04
# Epoch 3/60
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 8s 34ms/step - loss: 67.0209 - mae: 67.5187 - val_loss: 61.7444 - val_mae: 62.2420 - learning_rate: 1.0000e-04
# Epoch 4/60
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 8s 34ms/step - loss: 58.3344 - mae: 58.8309 - val_loss: 53.2871 - val_mae: 53.7840 - learning_rate: 1.0000e-04
# Epoch 5/60
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 8s 34ms/step - loss: 50.1410 - mae: 50.6380 - val_loss: 45.1106 - val_mae: 45.6062 - learning_rate: 1.0000e-04
# Epoch 6/60
# 221/222 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 44.3272 - mae: 44.8227
# Epoch 6: ReduceLROnPlateau reducing learning rate to 7.999999797903001e-05.
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 8s 34ms/step - loss: 42.1980 - mae: 42.6937 - val_loss: 37.1111 - val_mae: 37.6073 - learning_rate: 1.0000e-04
# Epoch 7/60
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 8s 34ms/step - loss: 35.3829 - mae: 35.8785 - val_loss: 31.1942 - val_mae: 31.6892 - learning_rate: 8.0000e-05
# Epoch 8/60
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 8s 34ms/step - loss: 30.0627 - mae: 30.5580 - val_loss: 25.9970 - val_mae: 26.4900 - learning_rate: 8.0000e-05
# Epoch 9/60
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 8s 34ms/step - loss: 25.4643 - mae: 25.9590 - val_loss: 21.8371 - val_mae: 22.3303 - learning_rate: 8.0000e-05
# Epoch 10/60
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 8s 34ms/step - loss: 22.1051 - mae: 22.5995 - val_loss: 18.8670 - val_mae: 19.3620 - learning_rate: 8.0000e-05
# Epoch 11/60
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 8s 34ms/step - loss: 19.3570 - mae: 19.8514 - val_loss: 16.4632 - val_mae: 16.9586 - learning_rate: 8.0000e-05
# Epoch 12/60
# 221/222 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 17.6350 - mae: 18.1296
# Epoch 12: ReduceLROnPlateau reducing learning rate to 6.399999838322402e-05.
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 8s 34ms/step - loss: 17.2735 - mae: 17.7681 - val_loss: 14.4470 - val_mae: 14.9417 - learning_rate: 8.0000e-05
# Epoch 13/60
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 8s 34ms/step - loss: 16.0207 - mae: 16.5139 - val_loss: 13.6140 - val_mae: 14.1091 - learning_rate: 6.4000e-05
# Epoch 14/60
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 8s 34ms/step - loss: 15.4863 - mae: 15.9797 - val_loss: 13.1130 - val_mae: 13.6072 - learning_rate: 6.4000e-05
# Epoch 15/60
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 7s 33ms/step - loss: 15.2057 - mae: 15.6976 - val_loss: 12.9549 - val_mae: 13.4485 - learning_rate: 6.4000e-05

# %%
# =========================================
# EVALUATION AND VISUALIZATION
# =========================================

# Validation Predictions
y_pred_ann = ann_model.predict(X_val).flatten()
y_pred_cnn = cnn_model.predict(X_val).flatten()
y_pred_lstm = lstm_model.predict(X_val).flatten()
y_pred_transformer = transformer_model.predict(X_val).flatten()

# Ensemble Prediction
ensemble_pred_val = 0.85 * y_pred_lstm + 0.15 * y_pred_cnn

# Metrics Function
def report_metrics(name, true, pred):
    mse = mean_squared_error(true, pred)
    rmse = np.sqrt(mse)
    mae = mean_absolute_error(true, pred)
    print(f"{name}: MSE={mse:.3f}, RMSE={rmse:.3f}, MAE={mae:.3f}")

# Validation Results
print("\n=== VALIDATION RESULTS ===")
report_metrics("ANN + Attention", y_val, y_pred_ann)
report_metrics("CNN + Attention", y_val, y_pred_cnn)
report_metrics("BiLSTM + Attention", y_val, y_pred_lstm)
report_metrics("Transformer", y_val, y_pred_transformer)
report_metrics("Ensemble", y_val, ensemble_pred_val)

# TEST SET EVALUATION

# Load and preprocess test data
test_df = pd.read_csv("test_FD001.txt", sep=r"\s+", header=None).iloc[:, :26]
test_df.columns = ['id','cycle','op1','op2','op3'] + [f's{i}' for i in range(1,22)]
test_df = test_df.drop(columns=drop_cols)
test_df[feature_cols] = scaler.transform(test_df[feature_cols])

# Build test sequences
X_test = []
for engine_id in test_df['id'].unique():
    engine_data = test_df[test_df['id'] == engine_id][feature_cols].values
    X_test.append(engine_data[-sequence_length:])
X_test = np.array(X_test)

# Load true RUL
y_test = pd.read_csv(
    "RUL_FD001.txt",
    header=None
).values.flatten()

# Test Predictions
pred_ann = ann_model.predict(X_test).flatten()
pred_cnn = cnn_model.predict(X_test).flatten()
pred_lstm = lstm_model.predict(X_test).flatten()
pred_transformer = transformer_model.predict(X_test).flatten()

# Ensemble
ensemble_pred_test = ( 0.85 * pred_lstm + 0.15 * pred_cnn)

# TEST RESULTS
print("\n=== TEST RESULTS ===")
report_metrics("ANN + Attention", y_test, pred_ann)
report_metrics("CNN + Attention", y_test, pred_cnn)
report_metrics("BiLSTM + Attention", y_test, pred_lstm)
report_metrics("Transformer", y_test, pred_transformer)
report_metrics("Ensemble", y_test, ensemble_pred_test)

# SAMPLE PREDICTIONS
print("\n=== SAMPLE PREDICTIONS ===\n")
for i in range(5):
    print(f"Engine {i+1}")
    print(f"Actual RUL      : {y_test[i]:.1f}")
    print(f"BiLSTM Predicted: {pred_lstm[i]:.1f}")
    print(f"Ensemble Predicted: {ensemble_pred_test[i]:.1f}")
    print("-" * 40)

# FINAL PLOT
plt.figure(figsize=(12,5))
plt.plot(y_test, label='Actual RUL', linewidth=2)
plt.plot(pred_lstm, label='BiLSTM + Attention', linewidth=1.5)
plt.plot(pred_transformer, label='Transformer', linewidth=1.5)
plt.plot(ensemble_pred_test, label='Ensemble', linewidth=2)
plt.title('Test Set: Actual vs Predicted RUL')
plt.xlabel('Engine Index')
plt.ylabel('RUL')
plt.legend()
plt.grid()
plt.show()

# RESIDUAL PLOT
ensemble_residuals = y_test - ensemble_pred_test
plt.figure(figsize=(10,4))
plt.scatter(range(len(ensemble_residuals)), ensemble_residuals, alpha=0.7)
plt.axhline(y=0, linestyle='--', color='black')
plt.title('Ensemble Residuals')
plt.xlabel('Engine Index')
plt.ylabel('Residual')
plt.grid()
plt.show()

# RUL DISTRIBUTION PLOT
plt.figure(figsize=(10,6))
plt.hist(train_df['RUL'], bins=40)
plt.xlabel("Remaining Useful Life (RUL)")
plt.ylabel("Frequency")
plt.title("RUL Distribution in CMAPSS FD001")
plt.show()
# Out:
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 5s 42ms/step
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step
#
# === VALIDATION RESULTS ===
# ANN + Attention: MSE=368.142, RMSE=19.187, MAE=14.746
# CNN + Attention: MSE=296.366, RMSE=17.215, MAE=12.076
# BiLSTM + Attention: MSE=169.522, RMSE=13.020, MAE=8.795
# Transformer: MSE=7734.838, RMSE=87.948, MAE=78.305
# Ensemble: MSE=170.344, RMSE=13.052, MAE=8.810
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
#
# === TEST RESULTS ===
# ANN + Attention: MSE=534.003, RMSE=23.109, MAE=17.097
# CNN + Attention: MSE=435.640, RMSE=20.872, MAE=15.459
# BiLSTM + Attention: MSE=252.246, RMSE=15.882, MAE=11.614
# Transformer: MSE=7063.036, RMSE=84.042, MAE=73.956
# Ensemble: MSE=252.189, RMSE=15.880, MAE=11.382
#
# === SAMPLE PREDICTIONS ===
#
# Engine 1
# Actual RUL      : 112.0
# BiLSTM Predicted: 121.9
# Ensemble Predicted: 121.9
# ----------------------------------------
# Engine 2
# Actual RUL      : 98.0
# BiLSTM Predicted: 124.4
# Ensemble Predicted: 125.0
# ----------------------------------------
# Engine 3
# Actual RUL      : 69.0
# BiLSTM Predicted: 42.4
# Ensemble Predicted: 44.3
# ----------------------------------------
# Engine 4
# Actual RUL      : 82.0
# BiLSTM Predicted: 75.9
# Ensemble Predicted: 79.9
# ----------------------------------------
# Engine 5
# Actual RUL      : 91.0
# BiLSTM Predicted: 95.3
# Ensemble Predicted: 96.8
# ----------------------------------------
